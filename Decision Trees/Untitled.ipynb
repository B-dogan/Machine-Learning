# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## regresyon problemi için örnek :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## R1 = 5.11 ------------> R1'deki noktaların ortalaması olduğuna dikkat edelim.class,f,cat,on problemi olsaydı en yüksek oy'a bakacaktık.
#
# ## ---------> regresyon probleminde gini ve entropiye göre değil   kareler toplamı.!!! kareler toplamı düşük olanı seçiyoruz.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # çünkü biz herhangi bir değişkeni 2'ye bölerek ilerliyoruz.

# %% [markdown]
# ## her bir nokta için bir bölge belirlersek ne olur -------> overfitting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ![image.png](attachment:image.png)

# %% [markdown]
# ## artık ortalama alamam çünkü çıktılarımız artık sürekli değil elmadan 5 tane armuttan 2 tane mi buna bakacağız.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## olası bir durumda ne kadar yanlış sınıflandırılır onun bir ölçüsüdür gini. o yüzden ginisi düşük olanı daha yukarıya koyuyoruz.

# %% [markdown]
# ## outlierlardan decision tree'ler etkilenmez.eksen olarak bölüyoruz yine scaling'e de bu yüzden ihtiyaç duymuyor aslında.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## regresyon problemlerinde label'ın ortalamasını alıp hatalara yüzdesel olarak bakmak önemli ;
# #### Iki veri seti düşünürsek biri gezegenlerin kütleleri ile ilgili olsun(Değerler büyük(Gezegen kütlesi) dolayısıyla tahmin değeri YAKIN olsa bile tahmin edilen değer ile gerçek değer arasındaki farkları alıp karesini alınca vs hata BÜYÜK GIBI görünecek). Mesela; RMSE :3115251.27 gelsin. Diğer veri seti çiçeklerin ağırlıkları olsun(Değerler küçük(çiçek ağırlığı) dolayısıyla tahmin değeri UZAK olsa bile tahmin edilen değer ile gerçek değer arasındaki farkları alıp karesini alınca vs hata KÜÇÜK GIBI görünecek)). Mesela RMSE: 7.9 gelsin. Bunlar bu arada scale edildikten sonraki hatalarımız. Sonuç: Şimdi RMSE hangisinde büyük diye düşünürsek bilemeyiz(Biliriz aslında describe a bakarak ama karşılaştırma yaparken zorlanabiliriz bazı durumlarda). Bunu oransal olarak görmek istediğimizde hatalara yüzdesel olarak bakmış oluyoruz.
