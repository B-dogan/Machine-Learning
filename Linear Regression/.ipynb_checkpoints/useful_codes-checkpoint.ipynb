# %%
ax = df.make_model.value_counts().plot(kind ="bar")

ax.bar_label(ax.containers[0]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_16284/35729690.py in <module>
# ----> 1 ax = df.make_model.value_counts().plot(kind ="bar")
#       2
#       3 ax.bar_label(ax.containers[0]);
#
# NameError: name 'df' is not defined

# %%
corr_by_target = X_train.join(y_train).corr()["target"].sort_values()[:-1]
corr_by_target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_16284/4210202260.py in <module>
# ----> 1 corr_by_target = X_train.join(y_train).corr()["target"].sort_values()[:-1]
#       2 corr_by_target
#
# NameError: name 'X_train' is not defined

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_23268/980480417.py in <module>
# ----> 1 print("Train features shape : ", X_train.shape)
#       2 print("Train target shape   : ", y_train.shape)
#       3 print("Test features shape  : ", X_test.shape)
#       4 print("Test target shape    : ", y_test.shape)
#
# NameError: name 'X_train' is not defined

# %%
coeff_df = pd.DataFrame(data = model.coef_ ,index=X.columns,columns = ["Coefficient"])
coeff_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_23268/4124924406.py in <module>
# ----> 1 coeff_df = pd.DataFrame(data = model.coef_ ,index=X.columns,columns = ["Coefficient"])
#       2 coeff_df
#
# NameError: name 'pd' is not defined

# %%
my_dict = {"Actual": y_test, "Pred": y_pred, "Residual":y_test-y_pred}
comparing = pd.DataFrame(my_dict)
comparing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_23268/1563543348.py in <module>
# ----> 1 my_dict = {"Actual": y_test, "Pred": y_pred, "Residual":y_test-y_pred}
#       2 comparing = pd.DataFrame(my_dict)
#       3 comparing
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ## Adjusted R2 score
#
# https://towardsdatascience.com/demystifying-r-squared-and-adjusted-r-squared-52903c006a60

# %%
def adj_r2(y_test, y_pred, X):
    r2 = r2_score(y_test, y_pred)
    n = X.shape[0]   # number of observations  
    p = X.shape[1]-1 # number of independent variables  
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %% [markdown]
# ## Evaluation Model

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance:")
    print("--------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %% [markdown]
# ### hem train hem test skorlarına bakmak istiyorum :

# %%
def train_val(y_train, y_train_pred, y_test, y_pred, name):
    
    scores = {name+"_train": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),                          
    "rmse" : np.sqrt(mean_squared_error(y_train, y_train_pred))},
    
    name+"_test": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : np.sqrt(mean_squared_error(y_test, y_pred))}}
    
    return pd.DataFrame(scores)

# %% [markdown]
# ## şu da kullanılabilir :

# %%
def train_val(model, X_train, y_train, X_test, y_test):
    
    y_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train)
    
    scores = {"train": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),                          
    "rmse" : np.sqrt(mean_squared_error(y_train, y_train_pred))},
    
    "test": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : np.sqrt(mean_squared_error(y_test, y_pred))}}
    
    return pd.DataFrame(scores)

# %%
model1 = train_val()
model2 = train_val()                     # bunları karşılaştırmak için :
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_14728/140633019.py in <module>
# ----> 1 model1 = train_val()
#       2 model2 = train_val()                     # bunları karşılaştırmak için :
#
# TypeError: train_val() missing 5 required positional arguments: 'y_train', 'y_train_pred', 'y_test', 'y_pred', and 'name'

# %%
pd.concat([ls, rs], axis=1)

# %% [markdown]
# ## featurelar arasında multicolinearty var mı ?

# %%
def color_red(val):
    if abs(val) > 0.90 and abs(val) < 0.99:
        color = 'red'
    else:
        color = 'black'
    return f'color: {color}'

# %% [markdown]
# ## or :

# %%
df_numeric.corr()[(df_numeric.corr()>= 0.9) & (df_numeric.corr() < 1)].any().any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_16284/2558993842.py in <module>
# ----> 1 df_numeric.corr()[(df_numeric.corr()>= 0.9) & (df_numeric.corr() < 1)].any().any()
#
# NameError: name 'df_numeric' is not defined

# %%
df_numeric.corr()[(df_numeric.corr()<= -0.9) & (df_numeric.corr() > -1)].any().any()         # heatmap ile de görebiliriz.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_16284/2651774544.py in <module>
# ----> 1 df_numeric.corr()[(df_numeric.corr()<= -0.9) & (df_numeric.corr() > -1)].any().any()         # heatmap ile de görebiliriz.
#
# NameError: name 'df_numeric' is not defined

# %% [markdown]
# ## Feature importances with Lasso

# %%
from yellowbrick.model_selection import FeatureImportances
from yellowbrick.features import RadViz

viz = FeatureImportances(lasso_cv_model, labels=pd.DataFrame(X_train).columns)
visualizer = RadViz(size=(720, 3000))                 # yellowbrick'İn figsize'ı bununla ayarlanııyor.
viz.fit(X_train, y_train)
viz.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_14728/163819007.py in <module>
#       2 from yellowbrick.features import RadViz
#       3
# ----> 4 viz = FeatureImportances(lasso_cv_model, labels=pd.DataFrame(X_train).columns)
#       5 visualizer = RadViz(size=(720, 3000))                 # yellowbrick'İn figsize'ı bununla ayarlanııyor.
#       6 viz.fit(X_train, y_train)
#
# NameError: name 'lasso_cv_model' is not defined

# %%
dir(model)        ## modelin içerisinde neler var ?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_14728/2177175540.py in <module>
# ----> 1 dir(model)        ## modelin içerisinde neler var ?
#
# NameError: name 'model' is not defined

# %%
# ?model
# Out:
# Object `model` not found.

# %% [markdown]
# ## alpha'nın en makul değerini yellowbrick ile de bulabiliriz:

# %%
from yellowbrick.regressor import ManualAlphaSelection

# Create a list of alphas to cross-validate against
alpha_space = np.linspace(0.1, 20, 100)


# Instantiate the visualizer
visualizer = ManualAlphaSelection(
    Ridge(),
    alphas=alpha_space,                                             # ridgecv yazmıyoruz buraya.
    cv=10,

)

visualizer.fit(X_train_scaled, y_train)
visualizer.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_14728/2592655568.py in <module>
#       2
#       3 # Create a list of alphas to cross-validate against
# ----> 4 alpha_space = np.linspace(0.1, 20, 100)
#       5
#       6
#
# NameError: name 'np' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## :

# %%
from yellowbrick.regressor import PredictionError
from yellowbrick.features import RadViz

visualizer = RadViz(size=(720, 3000))
model = LinearRegression()
visualizer = PredictionError(model)
visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_16284/2565089216.py in <module>
#       3
#       4 visualizer = RadViz(size=(720, 3000))
# ----> 5 model = LinearRegression()
#       6 visualizer = PredictionError(model)
#       7 visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
#
# NameError: name 'LinearRegression' is not defined

# %% [markdown]
# ## Feature İmportance

# %%
from yellowbrick.model_selection import FeatureImportances
from yellowbrick.features import RadViz

model = Lasso(alpha=1.02)              # ---------------> alpha dikkat

viz = FeatureImportances(model, labels=X_train.columns)
visualizer = RadViz(size=(720, 3000))
viz.fit(X_train_scaled, y_train)
viz.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_16284/1096651420.py in <module>
#       2 from yellowbrick.features import RadViz
#       3
# ----> 4 model = Lasso(alpha=1.02)              # ---------------> alpha dikkat
#       5
#       6 viz = FeatureImportances(model, labels=X_train.columns)
#
# NameError: name 'Lasso' is not defined

# %% [markdown]
# ## bu grafiğe bakarak 7-8 feature alsam acaba güzel bir skor alır mıyım diye deneyeceğiz . :

# %%
df_new = df3[["make_model", "hp_kW", "km","age", "price", "Gearing_Type", "Gears"]]
## df3 olduğuna dikkat edelim.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRKAN~1\AppData\Local\Temp/ipykernel_16284/2212426597.py in <module>
# ----> 1 df_new = df3[["make_model", "hp_kW", "km","age", "price", "Gearing_Type", "Gears"]]
#       2 ## df3 olduğuna dikkat edelim.
#
# NameError: name 'df3' is not defined
